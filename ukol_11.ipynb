# %%
import pandas as pd
import matplotlib.pyplot as plt
platy_02_2021 = pd.read_csv('platy_2021_02.csv')

# %%
platy_02_2021.hist('plat', bins=range(30000, 60000, 5000))
plt.show()

# %%
temperature = pd.read_csv('temperature.txt', sep=',')
temperature.head()
# Out:
#    Region  Country     City  Day  AvgTemperature
# 0  Africa  Algeria  Algiers    1            62.0
# 1  Africa  Algeria  Algiers    2            62.2
# 2  Africa  Algeria  Algiers    3            65.7
# 3  Africa  Algeria  Algiers    4            69.8
# 4  Africa  Algeria  Algiers    5            63.8

# %%
teploty = temperature[(temperature["City"] == "Helsinki") | (temperature["City"] == "Miami Beach") | (temperature["City"] == "Tokyo")]
teploty.boxplot(by='City', column='AvgTemperature')
plt.show()
